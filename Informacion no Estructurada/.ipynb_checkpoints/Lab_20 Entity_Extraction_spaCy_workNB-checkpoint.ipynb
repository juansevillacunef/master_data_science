# %% [markdown]
# # Extracción de entidades

# %%
# Importamos las librerías que corresponda
# Hay que añadir los modelos que se utilicen. Previamente cargados con python -m spacy download es_core_news_md

import spacy
from spacy import displacy
import pandas as pd

nlp_es = spacy.load('es_core_news_lg')

# %%
espa="Fue Carmen Martín Gaite (1925-2000) quien le enseñó a bailar a Luis Landero (Alburquerque, Badajoz, 1948). Lo suyo eran los pasodobles, esos bailes 'agarraos' en los que convenía dejarse llevar por una buena pareja. Y 'Carmiña' lo era. Eso y una gran conversadora, capaz de deleitar a su interlocutor con cuantos temas pasaran por su cabeza. Landero se acuerda de ello mientras observa, en su casa del madrileño barrio de Chamberí, los ejemplares de su amiga que tiene en una de sus librerías, donde los libros están ordenados alfabéticamente."
print(espa)
# Out:
# Fue Carmen Martín Gaite (1925-2000) quien le enseñó a bailar a Luis Landero (Alburquerque, Badajoz, 1948). Lo suyo eran los pasodobles, esos bailes 'agarraos' en los que convenía dejarse llevar por una buena pareja. Y 'Carmiña' lo era. Eso y una gran conversadora, capaz de deleitar a su interlocutor con cuantos temas pasaran por su cabeza. Landero se acuerda de ello mientras observa, en su casa del madrileño barrio de Chamberí, los ejemplares de su amiga que tiene en una de sus librerías, donde los libros están ordenados alfabéticamente.

# %%
# Ejecutamos la pipeline de análisis de Spacy
doc = nlp_es(espa)

# %%
# Imprimimos frases

for sent in doc.sents:
    print(sent.text)
# Out:
# Fue Carmen Martín Gaite (1925-2000) quien le enseñó a bailar a Luis Landero (Alburquerque, Badajoz, 1948).
# Lo suyo eran los pasodobles, esos bailes 'agarraos' en los que convenía dejarse llevar por una buena pareja.
# Y 'Carmiña' lo era.
# Eso y una gran conversadora, capaz de deleitar a su interlocutor con cuantos temas pasaran por su cabeza.
# Landero se acuerda de ello mientras observa, en su casa del madrileño barrio de Chamberí, los ejemplares de su amiga que tiene en una de sus librerías, donde los libros están ordenados alfabéticamente.

# %%
# Imprimimos entidades localizadas en el texto
# Out:
#                            0             1             2        3  \
# Entidad  Carmen Martín Gaite  Luis Landero  Alburquerque  Badajoz
# Tipo                     PER           PER           LOC      LOC
#
#                                    4            5  \
# Entidad  Lo suyo eran los pasodobles  Y 'Carmiña'
# Tipo                            MISC         MISC
#
#                                    6        7         8
# Entidad  Eso y una gran conversadora  Landero  Chamberí
# Tipo                            MISC      PER       LOC

# %%
# Entidades en el texto

for sent in docum_analizado.sents:
    displacy.render(sent, style='ent', jupyter=True, options={'distance': 110,'arrow_stroke': 2,'arrow_width': 8})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Fue
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Carmen Martín Gaite
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (1925-2000) quien le enseñó a bailar a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Luis Landero
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  (
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alburquerque
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Badajoz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , 1948). </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lo suyo eran los pasodobles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , esos bailes 'agarraos' en los que convenía dejarse llevar por una buena pareja. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Y 'Carmiña'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  lo era. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eso y una gran conversadora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , capaz de deleitar a su interlocutor con cuantos temas pasaran por su cabeza. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Landero
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  se acuerda de ello mientras observa, en su casa del madrileño barrio de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chamberí
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , los ejemplares de su amiga que tiene en una de sus librerías, donde los libros están ordenados alfabéticamente.</div></span>

# %%
# Diagrama de Dependencias

for sent in docum_analizado.sents:
    displacy.render(sent, jupyter=True, options={'distance': 110,'arrow_stroke': 2,'arrow_width': 8})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="639f457e03d44879a22fc79e9eaacf59-0" class="displacy" width="1810" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Fue</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">Carmen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">Martín</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">Gaite (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">1925-2000)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">quien</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">le</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">enseñó</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">bailar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">Luis</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">Landero (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">Alburquerque,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">Badajoz,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">1948).</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-639f457e03d44879a22fc79e9eaacf59-0-0" stroke-width="2px" d="M70,222.0 C70,167.0 145.0,167.0 145.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-639f457e03d44879a22fc79e9eaacf59-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,224.0 L64,214.0 76,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-639f457e03d44879a22fc79e9eaacf59-0-1" stroke-width="2px" d="M180,222.0 C180,167.0 255.0,167.0 255.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-639f457e03d44879a22fc79e9eaacf59-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M255.0,224.0 L261.0,214.0 249.0,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-639f457e03d44879a22fc79e9eaacf59-0-2" stroke-width="2px" d="M180,222.0 C180,112.0 370.0,112.0 370.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-639f457e03d44879a22fc79e9eaacf59-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370.0,224.0 L376.0,214.0 364.0,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-639f457e03d44879a22fc79e9eaacf59-0-3" stroke-width="2px" d="M180,222.0 C180,57.0 485.0,57.0 485.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-639f457e03d44879a22fc79e9eaacf59-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M485.0,224.0 L491.0,214.0 479.0,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-639f457e03d44879a22fc79e9eaacf59-0-4" stroke-width="2px" d="M620,222.0 C620,112.0 810.0,112.0 810.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-639f457e03d44879a22fc79e9eaacf59-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M620,224.0 L614,214.0 626,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-639f457e03d44879a22fc79e9eaacf59-0-5" stroke-width="2px" d="M730,222.0 C730,167.0 805.0,167.0 805.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-639f457e03d44879a22fc79e9eaacf59-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">iobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M730,224.0 L724,214.0 736,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-639f457e03d44879a22fc79e9eaacf59-0-6" stroke-width="2px" d="M180,222.0 C180,2.0 820.0,2.0 820.0,222.0" fill="none" stroke="curren
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="f3f25fedeee34a3ab0a3fd34c3b3dfb7-0" class="displacy" width="2030" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Lo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">suyo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">eran</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">los</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">pasodobles,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">esos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">bailes '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">agarraos'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">los</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">convenía</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">dejarse</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">llevar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">una</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">buena</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">pareja.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3f25fedeee34a3ab0a3fd34c3b3dfb7-0-0" stroke-width="2px" d="M70,222.0 C70,167.0 145.0,167.0 145.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f3f25fedeee34a3ab0a3fd34c3b3dfb7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,224.0 L64,214.0 76,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3f25fedeee34a3ab0a3fd34c3b3dfb7-0-1" stroke-width="2px" d="M180,222.0 C180,57.0 485.0,57.0 485.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f3f25fedeee34a3ab0a3fd34c3b3dfb7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,224.0 L174,214.0 186,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3f25fedeee34a3ab0a3fd34c3b3dfb7-0-2" stroke-width="2px" d="M290,222.0 C290,112.0 480.0,112.0 480.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f3f25fedeee34a3ab0a3fd34c3b3dfb7-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,224.0 L284,214.0 296,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3f25fedeee34a3ab0a3fd34c3b3dfb7-0-3" stroke-width="2px" d="M400,222.0 C400,167.0 475.0,167.0 475.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f3f25fedeee34a3ab0a3fd34c3b3dfb7-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,224.0 L394,214.0 406,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3f25fedeee34a3ab0a3fd34c3b3dfb7-0-4" stroke-width="2px" d="M620,222.0 C620,167.0 695.0,167.0 695.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f3f25fedeee34a3ab0a3fd34c3b3dfb7-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M620,224.0 L614,214.0 626,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f3f25fedeee34a3ab0a3fd34c3b3dfb7-0-5" stroke-width="2px" d="M510,222.0 C510,112.0 700.0,112.0 700.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f3f25f
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="b86fa1a3a7404441be31499adb363b2d-0" class="displacy" width="490" height="247.0" direction="ltr" style="max-width: none; height: 247.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Y '</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">Carmiña'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">lo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">era.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">AUX</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b86fa1a3a7404441be31499adb363b2d-0-0" stroke-width="2px" d="M70,112.0 C70,2.0 270.0,2.0 270.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b86fa1a3a7404441be31499adb363b2d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,114.0 L64,104.0 76,104.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b86fa1a3a7404441be31499adb363b2d-0-1" stroke-width="2px" d="M180,112.0 C180,57.0 265.0,57.0 265.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b86fa1a3a7404441be31499adb363b2d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,114.0 L174,104.0 186,104.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b86fa1a3a7404441be31499adb363b2d-0-2" stroke-width="2px" d="M290,112.0 C290,57.0 375.0,57.0 375.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b86fa1a3a7404441be31499adb363b2d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M375.0,114.0 L381.0,104.0 369.0,104.0" fill="currentColor"/>
# </g>
# </svg></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="eb35f9c78aed40ecab043956bd5b1399-0" class="displacy" width="2030" height="467.0" direction="ltr" style="max-width: none; height: 467.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Eso</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">y</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">una</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">gran</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">conversadora,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">capaz</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">deleitar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">su</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">interlocutor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">con</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">cuantos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">temas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">pasaran</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">por</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">su</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">cabeza.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-eb35f9c78aed40ecab043956bd5b1399-0-0" stroke-width="2px" d="M180,332.0 C180,167.0 475.0,167.0 475.0,332.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-eb35f9c78aed40ecab043956bd5b1399-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,334.0 L174,324.0 186,324.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-eb35f9c78aed40ecab043956bd5b1399-0-1" stroke-width="2px" d="M290,332.0 C290,222.0 470.0,222.0 470.0,332.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-eb35f9c78aed40ecab043956bd5b1399-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,334.0 L284,324.0 296,324.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-eb35f9c78aed40ecab043956bd5b1399-0-2" stroke-width="2px" d="M400,332.0 C400,277.0 465.0,277.0 465.0,332.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-eb35f9c78aed40ecab043956bd5b1399-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,334.0 L394,324.0 406,324.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-eb35f9c78aed40ecab043956bd5b1399-0-3" stroke-width="2px" d="M70,332.0 C70,112.0 480.0,112.0 480.0,332.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-eb35f9c78aed40ecab043956bd5b1399-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M480.0,334.0 L486.0,324.0 474.0,324.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-eb35f9c78aed40ecab043956bd5b1399-0-4" stroke-width="2px" d="M510,332.0 C510,277.0 575.0,277.0 575.0,332.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-eb35f9c78aed40ecab043956bd5b1399-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,334.0 L581.0,324.0 569.0,324.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-eb35f9c78aed40ecab043956bd5b1399-0-5" stroke-width="2px" d="M730,332.0 C730,277.0 795.0,277.0 795.0,332.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="16585e7c0be04b72a184b9a61b13369a-0" class="displacy" width="3680" height="467.0" direction="ltr" style="max-width: none; height: 467.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Landero</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">se</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">acuerda</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">ello</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">mientras</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">observa,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">su</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">casa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">del</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">madrileño</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">barrio</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">Chamberí,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">los</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">ejemplares</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">su</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">amiga</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2360">tiene</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2360">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2470">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2470">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2580">una</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2580">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2800">sus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2910">librerías,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2910">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="3020">donde</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3020">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="3130">los</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="3240">libros</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3240">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">están</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">AU
